# %%
# %load_ext autoreload
# %autoreload 2
    
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdate
import datetime as dt
from tqdm import tqdm
from glob import glob
import re
from pathlib import Path
import plotly.graph_objects as go
import plotly.io as pio
pio.renderers.default = 'notebook'

try: 
    import dunestyle.matplotlib as dunestyle
    from cycler import cycler
    plt.rcParams['axes.facecolor'] = '#ffffff'
    plt.rcParams['figure.facecolor'] = '#ffffff'
    plt.rcParams['savefig.facecolor'] = '#ffffff'
    plt.rcParams.update(
        {
        "axes.prop_cycle":cycler(color=['#1f77b4',
                                        '#ff7f0e',
                                        '#2ca02c',
                                        '#d62728',
                                        '#9467bd',
                                        '#8c564b',
                                        '#e377c2',
                                        '#7f7f7f',
                                        '#bcbd22',
                                        '#17becf'])
        })
        
except Exception as e:
    print("Using mplhep... ", e)
    import mplhep
    mplhep.style.use(mplhep.style.ROOT)
    plt.rcParams.update({
                         #'font.size': 23,
                         'grid.linestyle': '--',
                         'axes.grid': True,
                         'figure.autolayout': True,
                         'figure.figsize': [14,6],
                        #  'font.family': 'sans-serif',
                        #  'font.sans-serif': ['Helvetica', 'Helvetica Neue', 'Nimbus Sans', 'Liberation Sans', 'Arial']
                         })
import sys
sys.path.insert(1, '../')
from waffles.np02_utils.AutoMap import getModuleName
from utils import PATH_XE_OUTPUTS
from utils_monitoring import load_database, load_fit_results, make_relative_cols, load_injections, load_results
from utils_monitoring import plot_vs_time_per_channel, iplot, execute_by_module

# %%
df_injections = load_injections()
df_injections

# %%
analysisname = 'analysis_results_few_cuts-gpiemont'
path_with_analysis = Path(PATH_XE_OUTPUTS)

# %%
dfres = load_results(analysisname=analysisname, path_with_analysis=path_with_analysis, load_hv=False, how='inner')
dfdeconv = dfres['deconv']
dfconv = dfres['conv']
dfdeconv

# %%
analysisname_test = 'analysis_results_few_cuts-hvieirad'
path_with_analysis = Path(PATH_XE_OUTPUTS)

# %%
dfres_1 = load_results(analysisname=analysisname_test, path_with_analysis=path_with_analysis, load_hv=False, how='inner')
dfdeconv_1 = dfres_1['deconv']
dfconv_1 = dfres_1['conv']
dfdeconv_1

# %%
for df in dfres.values():
    df = make_relative_cols(df, "ppm")

# %%
for df1 in dfres_1.values():
    df1 = make_relative_cols(df1, "ppm")

# %%
modules_ok = ['C3']
# modules_ok = ['M']
# modules_ok = ['C1', 'C3(1)', 'C7']
# modules_ok = ['M5', 'M6', 'M7', 'M8'] 
y = 't3[ns]'
x = 'time'

print("conv")
fig = go.Figure()
execute_by_module(dfres['conv'], iplot, fig=fig, y=y, x=x, modules=modules_ok, df_injections=df_injections)
execute_by_module(dfres_1['conv'], iplot, fig=fig, y=y, x=x, modules=modules_ok, df_injections=df_injections, color="black")

fig.show()

print("deconv")
fig = go.Figure()
execute_by_module(dfres['deconv'], iplot, fig=fig, y=y, x=x, modules=modules_ok, df_injections=df_injections)
execute_by_module(dfres_1['deconv'], iplot, fig=fig, y=y, x=x, modules=modules_ok, df_injections=df_injections, color="black")

fig.show()

# %%
plt.figure(figsize=(14,6))
df = dfres['conv']
# plot_vs_time_per_channel(df, y='t3[ns]',  module="C3(1)", showhours=True)
# plot_vs_time_per_channel(df, y='t3[ns]',  module="C3(1)", xlim=(pd.to_datetime('2025-09-19 8:00'), pd.to_datetime('2025-09-19 16:30')), showhours=True, label="C3(1)")
plot_vs_time_per_channel(df, y='t3[ns]',  module="C3(1)", showhours=True, label="C3(2)", df_injections=df_injections)
plot_vs_time_per_channel(df, y='t3[ns]',  module="C3(2)", showhours=True, label="C3(2)", df_injections=df_injections)
# Add shaded regions after all modules are plotted
plt.show()

# %%
plt.figure(figsize=(14,6))
# plot_vs_time_per_channel(df, y='t3[ns]',  module="C3(1)", showhours=True)
execute_by_module(df,
                  plot_vs_time_per_channel,
                  modules=["C"],
                  y='t3[ns]',
                  # xlim=(pd.to_datetime('2025-09-19 8:00'), pd.to_datetime('2025-09-19 16:30')),
                  showhours=True,
                  autolabel=True,
                  legendoutside=True,
                  dotitle=False,
                  df_injections=df_injections
                 )
