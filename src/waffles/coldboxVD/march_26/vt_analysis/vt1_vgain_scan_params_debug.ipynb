# %% [markdown]
# Vgain analysis debug
#
# to find optimal parameters

# %%
# %load_ext autoreload
# %autoreload 2

from waffles.coldboxVD.march_26.analysis.utils import *

from pathlib import Path

# %%
# VD modules analysis 


# # 1. Analyzing Vgain scan of 25/03/2026

membrane = 'M1'
channel = 1
led = 730
bias = 1169 # +3 1143, +4 1169, +5 1195 OV (HPK) 
output_files_comment = ''

 

input_file = (
    "/eos/experiment/neutplatform/protodune/experiments/ColdBoxVD/"
    "March2026run/VD/BiasVGainScan_20260325/"
    "afe0bias_{bias}/"
    "vgain_{vgain}/"
    "led_{led}_ch{channel}/"
    "channel_{channel}.dat"
)

base_dir = Path.cwd()

json_path = f"input/json_files/vgain_parameters_{membrane}_ch{channel}_bias{bias:04d}_led{led}.json"

# %%
## -- from input file --

with open(json_path, "r") as f:
    dict_params_all = json.load(f)
dict_params_all = {int(k): v for k, v in dict_params_all.items()}

# %%
# single_vgain_analysis(membrane = membrane, 
#                     channel = channel, 
#                     bias = bias, 
#                     vgain = vgain,
#                     led = led,
#                     input_file= input_file,
#                     dict_params = vgain_analysis_parameters[vgain],
#                     save_pdf = False,
#                     output_files_comment = output_files_comment,
#                     show = True)

# %%
channel_vgain_scan_analysis(
                    membrane = membrane, 
                    channel = channel, 
                    bias = bias,
                    #vgain_list = list(map(int, dict_params_all.keys())), #range(600, 801, 100), #or dict_params_all.keys(),
                    vgain_list = list(range(1500, 2301, 100)),
                    led = led,
                    external_dict_paramas = dict_params_all, # OPTIONAL!!! if it is given, it uses params form the given out. else outomatically computed by vgain_analysis_parameters() --> it is not working weel yet
                    input_filename_path_style = input_file, #info to reconstruct the path
                    input_filename_variable = ['bias', 'vgain', 'led', 'channel'], #info to reconstruct the path 
                    show = False,
                    save_pdf = True,
                    output_files_comment = output_files_comment
                    )
# Out:
# ------------------------------------------------------------------------
#
# ------ Membrane: M1 - Channel: 1 - Led: 730 - Bias: 1143 - Vgain: 1500 ------
#
# The file has been correctly read
# 0 16383
# Pdf saved : output/membrane_M1/channel_1/bias_1143/membraneM1_channel1_led730_bias1143_vgain1500.pdf
#
#
#
# ------------------------------------------------------------------------
#
# ------ Membrane: M1 - Channel: 1 - Led: 730 - Bias: 1143 - Vgain: 1600 ------
#
# The file has been correctly read
# 0 16383
# Pdf saved : output/membrane_M1/channel_1/bias_1143/membraneM1_channel1_led730_bias1143_vgain1600.pdf
#
#
#
# ------------------------------------------------------------------------
#
# ------ Membrane: M1 - Channel: 1 - Led: 730 - Bias: 1143 - Vgain: 1700 ------
#
# The file has been correctly read
# 412 16383
# Pdf saved : output/membrane_M1/channel_1/bias_1143/membraneM1_channel1_led730_bias1143_vgain1700.pdf
#
#
#
# ------------------------------------------------------------------------
#
# ------ Membrane: M1 - Channel: 1 - Led: 730 - Bias: 1143 - Vgain: 1800 ------
#
# The file has been correctly read
# 1683 16383
# Pdf saved : output/membrane_M1/channel_1/bias_1143/membraneM1_channel1_led730_bias1143_vgain1800.pdf
#
#
#
# ------------------------------------------------------------------------
#
# ------ Membrane: M1 - Channel: 1 - Led: 730 - Bias: 1143 - Vgain: 1900 ------
#
# The file has been correctly read
# 569 16383
# Pdf saved : output/membrane_M1/channel_1/bias_1143/membraneM1_channel1_led730_bias1143_vgain1900.pdf
#
#
#
# ------------------------------------------------------------------------
#
# ------ Membrane: M1 - Channel: 1 - Led: 730 - Bias: 1143 - Vgain: 2000 ------
#
# The file has been correctly read
# 2638 16383
# Pdf saved : output/membrane_M1/channel_1/bias_1143/membraneM1_channel1_led730_bias1143_vgain2000.pdf
#
#
#
# ------------------------------------------------------------------------
#
# ------ Membrane: M1 - Channel: 1 - Led: 730 - Bias: 1143 - Vgain: 2100 ------
#
# The file has been correctly read
# 1877 16383
# Pdf saved : output/membrane_M1/channel_1/bias_1143/membraneM1_channel1_led730_bias1143_vgain2100.pdf
#
#
#
# ------------------------------------------------------------------------
#
# ------ Membrane: M1 - Channel: 1 - Led: 730 - Bias: 1143 - Vgain: 2200 ------
#
# The file has been correctly read
# 4575 16383
# Pdf saved : output/membrane_M1/channel_1/bias_1143/membraneM1_channel1_led730_bias1143_vgain2200.pdf
#
# Results in output/membrane_M1/channel_1/bias_1143
