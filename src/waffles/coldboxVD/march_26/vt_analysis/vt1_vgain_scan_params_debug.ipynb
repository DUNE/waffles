# %% [markdown]
# Vgain analysis debug
#
# to find optimal parameters

# %%
# %load_ext autoreload
# %autoreload 2

from waffles.coldboxVD.march_26.analysis.utils import *

# %%
# VD modules analysis 


# # 1. Analyzing Vgain scan of 25/03/2026

membrane = 'M1'
channel = 1
led = 730
bias = 1195 # OV HPK
output_files_comment = ''

 

input_file = (
    "/eos/experiment/neutplatform/protodune/experiments/ColdBoxVD/"
    "March2026run/VD/BiasVGainScan_20260325/"
    "afe0bias_{bias}/"
    "vgain_{vgain}/"
    "led_{led}_ch{channel}/"
    "channel_{channel}.dat"
)

json_path = f"input/json_files/vgain_parameters_{membrane}_ch{channel}_bias{bias:04d}_led{led}.json"

# %%
## -- from input file --

with open(json_path, "r") as f:
    dict_params_all = json.load(f)
dict_params_all = {int(k): v for k, v in dict_params_all.items()}

# %%
# single_vgain_analysis(membrane = membrane, 
#                     channel = channel, 
#                     bias = bias, 
#                     vgain = vgain,
#                     led = led,
#                     input_file= input_file,
#                     dict_params = vgain_analysis_parameters[vgain],
#                     save_pdf = False,
#                     output_files_comment = output_files_comment,
#                     show = True)

# %%
channel_vgain_scan_analysis(
                    membrane = membrane, 
                    channel = channel, 
                    bias = bias,
                    vgain_list = list(map(int, dict_params_all.keys())), #range(600, 801, 100), #or dict_params_all.keys(),
                    led = led,
                    external_dict_paramas = dict_params_all, # OPTIONAL!!! if it is given, it uses params form the given out. else outomatically computed by vgain_analysis_parameters() --> it is not working weel yet
                    input_filename_path_style = input_file, #info to reconstruct the path
                    input_filename_variable = ['bias', 'vgain', 'led', 'channel'], #info to reconstruct the path 
                    show = False,
                    save_pdf = True,
                    output_files_comment = output_files_comment
                    )
# Out:
# [1500, 1600, 1700, 1800, 1900, 2000, 2100, 2200, 2300, 2400, 2500, 2600]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 channel_vgain_scan_analysis(
#       2                     membrane = membrane,
#       3                     channel = channel,
#       4                     bias = bias,
#       5                     vgain_list = list(map(int, dict_params_all.keys())), #range(600, 801, 100), #or dict_params_all.keys(),
#       6                     led = led,
#       7                     external_dict_paramas = dict_params_all, # OPTIONAL!!! if it is given, it uses params form the given out. else outomatically computed by vgain_analysis_parameters() --> it is not working weel yet
#       8                     input_filename_path_style = input_file, #info to reconstruct the path
#       9                     input_filename_variable = ['bias', 'vgain', 'led', 'channel'], #info to reconstruct the path
#      10                     show = False,
#      11                     save_pdf = True,
#      12                     output_files_comment = output_files_comment
#      13                     )
#
# File /eos/home-v/vtrabatt/waffles/src/waffles/coldboxVD/march_26/analysis/utils.py:843, in channel_vgain_scan_analysis(membrane, channel, bias, vgain_list, led, input_filename_path_style, input_filename_variable, external_dict_paramas, show, save_pdf, output_folder, output_files_comment, parameters_conversion)
#     835 for vgain in vgain_list:
#     836     input_file = _build_input_filepath(
#     837         input_filename_path_style,
#     838         bias=bias,
#    (...)
#     841         channel=channel,
#     842     )
# --> 843     row = single_vgain_analysis(
#     844         membrane=membrane,
#     845         channel=channel,
#     846         bias=bias,
#     847         vgain=vgain,
#     848         led = led,
#     849         dict_params = (external_dict_paramas[vgain] if external_dict_paramas is not None else vgain_analysis_parameters(vgain)),
#     850         input_file= input_file,
#     851         parameters_conversion = parameters_conversion,
#     852         output_folder = output_folder_analysis,
#     853         output_files_comment = output_files_comment,
#     854         show = show,
#     855         save_pdf = save_pdf
#     856     )
#     858     rows.append(row)
#     860 out_df = pd.DataFrame(rows)
#
# File /eos/home-v/vtrabatt/waffles/src/waffles/coldboxVD/march_26/analysis/utils.py:590, in single_vgain_analysis(membrane, channel, bias, vgain, led, dict_params, input_file, show, save_pdf, parameters_conversion, output_folder, output_files_comment)
#     588 # Check existance of input file
#     589 if not os.path.exists(input_file):
# --> 590     raise FileNotFoundError(f"File non trovato: {input_file}")
#     592 print(f"\n\n------------------------------------------------------------------------ \n\n------ Membrane: {membrane} - Channel: {channel} - Led: {led} - Bias: {bias} - Vgain: {vgain} ------\n")
#     595 wfset_original = create_waveform_set_from_spybuffer(filename=input_file, WFs=40000, length=1024, config_channel=channel)
#
# FileNotFoundError: File non trovato: /eos/experiment/neutplatform/protodune/experiments/ColdBoxVD/March2026run/VD/BiasVGainScan/afe1bias_1195/vgain_1500/led_730_ch1/channel_1.dat
