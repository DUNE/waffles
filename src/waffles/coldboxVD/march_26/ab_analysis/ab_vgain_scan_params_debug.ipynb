# %% [markdown]
# Vgain analysis debug
#
# to find optimal parameters

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline


from waffles.coldboxVD.march_26.analysis.utils import *

# %%
# HD modules analysis 


# # 1. Analyzing Vgain scan of 23/03/2026

membrane = 'M3'
channel = 12
led = 1100
bias = 810 #+4,5 OV (FBK)
output_files_comment = ''


input_file = "/eos/experiment/neutplatform/protodune/experiments/ColdBoxVD/March2026run/HD/BiasVGainScan/afe1bias_{bias:04d}/vgain_{vgain:04d}/led_{led}_ch{channel}/channel_{channel}.dat"
json_path = f"input/json_files/vgain_parameters_{membrane}_ch{channel}_bias{bias:04d}_led{led}.json"


# # 2. Analyzing Vgain scan of 24/03/2026

# membrane = 'M3'
# channel = 8
# led = 830
# bias = 810 #+4,5 OV (FBK)
# output_files_comment = '20260324'

# vgain = 800
 
# input_file = f"/eos/experiment/neutplatform/protodune/experiments/ColdBoxVD/March2026run/HD/BiasVGainScan_20260324/vgain_{vgain:04d}/afe1bias_{bias:04d}/led_{led}_ch{channel}/channel_{channel}.dat"
# json_path = f"input/json_files/vgain_parameters_{membrane}_ch{channel}_bias{bias:04d}_led{led}_20260324.json"

# %%
## -- from input file --

with open(json_path, "r") as f:
    dict_params_all = json.load(f)
dict_params_all = {int(k): v for k, v in dict_params_all.items()}

# %%
# vgain = 800

# dict_params = dict_params_all[vgain] 

# input_file_reading  = input_file.format(
#     bias=bias,
#     vgain=vgain,
#     led=led,
#     channel=channel
# )

# single_vgain_analysis(membrane = membrane, 
#                     channel = channel, 
#                     bias = bias, 
#                     vgain = vgain,
#                     led = led,
#                     input_file= input_file_reading,
#                     dict_params = dict_params, #vgain_analysis_parameters[vgain],
#                     save_pdf = False,
#                     output_files_comment = output_files_comment,
#                     show = True)

# %%
channel_vgain_scan_analysis(
                    membrane = membrane, 
                    channel = channel, 
                    bias = bias,
                    vgain_list = list(map(int, dict_params_all.keys())), #range(600, 801, 100), #or dict_params_all.keys(),
                    led = led,
                    external_dict_paramas = dict_params_all, # OPTIONAL!!! if it is given, it uses params form the given out. else outomatically computed by vgain_analysis_parameters() --> it is not working weel yet
                    input_filename_path_style = input_file, #info to reconstruct the path
                    input_filename_variable = ['bias', 'vgain', 'led', 'channel'], #info to reconstruct the path 
                    show = False,
                    save_pdf = True,
                    output_files_comment = output_files_comment
                    )

# %%
# "500" : {
#         "baseline_timeticks_limit": 125, 
#         "deviation_upper_limit": null, 
#         "fixed_integral_limits" : [126,150],
#         "heatmap_min": -170,
#         "heatmap_max": 550,
#         "adcs_threshold": 120, 
#         "n_std_baseline": 1.2, 
#         "max_peaks": 5,
#         "prominence": 0.99,
#         "initial_percentage": 0.3,
#         "percentage_step": 0.6,
#         "ch_span_fraction_around_peaks": 0.5,
#         "time_range_afterpulse_for_meanwf": [300,-1]
#     },
#     "600" : {
#         "baseline_timeticks_limit": 125, 
#         "deviation_upper_limit": null, 
#         "fixed_integral_limits" : [126,150],
#         "heatmap_min": -170,
#         "heatmap_max": 550,
#         "adcs_threshold": 85, 
#         "n_std_baseline": 1.15, 
#         "max_peaks": 6,
#         "prominence": 0.95,
#         "initial_percentage": 0.1,
#         "percentage_step": 0.4,
#         "ch_span_fraction_around_peaks": 0.05,
#         "time_range_afterpulse_for_meanwf": [300,-1]
#     },
# "2000":  {
#     "baseline_timeticks_limit": 125, 
#     "deviation_upper_limit": null, 
#     "fixed_integral_limits" : [126,150],
#     "heatmap_min": -50,
#     "heatmap_max": 100,
#     "adcs_threshold": 12, 
#     "n_std_baseline": 1, 
#     "max_peaks": 5,
#     "prominence": 0.2,
#     "initial_percentage": 0.2,
#     "percentage_step": 0.02,
#     "ch_span_fraction_around_peaks": 0.02,
#     "time_range_afterpulse_for_meanwf": [500,-1]
#     },
